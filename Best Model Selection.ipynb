# %%
import pickle
import pandas as pd

# %%
path_pickles = r"C:\Users\Saran Sai\Desktop\AI- UNT\Feature Engineering\ICE-1\04 Model Training\Models"

list_pickles = [
    "\df_models_gbc.pickle",
    "\df_models_knnc.pickle",
    "\df_models_lrc.pickle",
    "\df_models_mnbc.pickle",
    "\df_models_rfc.pickle",
    "\df_models_svc.pickle"
]

df_summary = pd.DataFrame()

for pickle_ in list_pickles:
    
    path = path_pickles + pickle_
    
    with open(path, 'rb') as data:
        df = pickle.load(data)

    df_summary = df_summary.append(df)

df_summary = df_summary.reset_index().drop('index', axis=1)

# %%
df_summary
# Out:
#                      Model  Training Set Accuracy  Test Set Accuracy
# 0        Gradient Boosting               0.995680           0.939024
# 1                      KNN               0.995680           0.701220
# 2      Logistic Regression               0.977322           0.957317
# 3  Multinomial Naïve Bayes               0.951404           0.945122
# 4            Random Forest               0.994600           0.926829
# 5                      SVM               0.916847           0.878049

# %%
df_summary.sort_values('Test Set Accuracy', ascending=False)
# Out:
#                      Model  Training Set Accuracy  Test Set Accuracy
# 2      Logistic Regression               0.977322           0.957317
# 3  Multinomial Naïve Bayes               0.951404           0.945122
# 0        Gradient Boosting               0.995680           0.939024
# 4            Random Forest               0.994600           0.926829
# 5                      SVM               0.916847           0.878049
# 1                      KNN               0.995680           0.701220
